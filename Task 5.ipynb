# %%
import matplotlib.pyplot as plt

# Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2)

# Plot a bar chart in the top-left subplot
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [23, 56, 41, 62, 19]
axes[0, 0].bar(categories, values)
axes[0, 0].set_title('Bar Chart')
axes[0, 0].set_xlabel('Categories')
axes[0, 0].set_ylabel('Values')

# Plot a histogram in the top-right subplot
data = [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]
axes[0, 1].hist(data)
axes[0, 1].set_title('Histogram')
axes[0, 1].set_xlabel('Data')
axes[0, 1].set_ylabel('Frequency')

# Plot a pie chart in the bottom-left subplot
labels = ['Apple', 'Banana', 'Orange', 'Mango']
sizes = [30, 25, 15, 30]
axes[1, 0].pie(sizes, labels=labels)
axes[1, 0].set_title('Pie Chart')
axes[1, 0].legend()

# Plot a scatter plot in the bottom-right subplot
x_values = [1, 2, 3, 4, 5]
y_values = [2, 5, 3, 6, 4]
axes[1, 1].scatter(x_values, y_values)
axes[1, 1].set_title('Scatter Plot')
axes[1, 1].set_xlabel('X values')
axes[1, 1].set_ylabel('Y values')

# Adjust the spacing between subplots to avoid overlapping
plt.subplots_adjust(wspace=0.5, hspace=0.5)

# Show the figure
plt.show()
